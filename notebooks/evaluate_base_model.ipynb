# %%
import sys
sys.path.append('../')

# %%
from utils.llm import CustomLLM
import configparser

config = configparser.ConfigParser()
config.read('../config.ini')
# Out:
# ['../config.ini']

# %%
llm = CustomLLM()

# %%
prompt = llm.format_prompt(user_query="Who is your favorite friends character", system_instruction=config.get('llm.prompt', 'system_instruction'))

# %%
print(llm(prompt))
# Out:
#   My favorite Friends character is Joey Tribbiani. His funny one-liners and lovable personality make him a standout character in the show.

# %%
import pandas as pd
from pandas import json_normalize
from tqdm import tqdm

# %%
data = pd.read_csv('../data/eval_data/trivia_data.csv')
# data = pd.read_csv('../data/eval_data/trivia_data_with_response.csv')

# %%
data.columns = ['question', 'options', 'reference', 'correct_option']

# %%
# Get base model response

questions = data['question'].tolist()
responses = []

for question in tqdm(questions):
    prompt = llm.format_prompt(user_query=question, system_instruction=config.get('llm.prompt', 'system_instruction'))
    response = await llm.ainvoke(prompt)
    responses.append(response)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# 100%|██████████| 200/200 [04:16<00:00,  1.28s/it]

# %%
data['response'] = responses

# %%
data.to_csv('../data/eval_data/trivia_data_with_base_response.csv', index=False)

# %%
data
# Out:
#                                               question  \
# 0        How many times was Ross legally divorced?  \n
# 1                Where did Carol first meet Susan?  \n
# 2      How did Susan and Ross come up with Ben’s name?
# 3                     What were Ben's first words?  \n
# 4    How long did Ross and Emily date before they g...
# ..                                                 ...
# 96              Which actor's haircut did Monica want?
# 97   What city does the Mama's Little Bakery cheese...
# 98   After reading _Be Your Own Windkeeper_, who do...
# 99   When Ben shows up with a Barbie doll, what dol...
# 100  Who did Chandler’s dad dress up as when he wen...
#
#                                                options  \
# 0          [Twice, Three times, Five times, Six times]
# 1    [In college, At work, At the gym, At Central P...
# 2    [It was the doctor's name, They both had uncle...
# 3                                 [Hi, Bye, Mom, Dumb]
# 4                 [14 days, 6 weeks, A year, 3 months]
# ..                                                 ...
# 96   [Winona Ryder, Demi Moore, Terri Hatcher, Juli...
# 97   [Albany, New York, Chicago, Illinois, Boston, ...
# 98   [Rachel, Monica, None of the above, All of the...
# 99   [Action Man, GI Joe, Optimus Prime, Stretch Ar...
# 100  [Marilyn Monroe, Carmen Miranda, Mae West, Luc...
#
#                             reference correct_option  \
# 0                         Three times              B
# 1                          At the gym              C
# 2    It was on the janitor's name tag              D
# 3                                  Hi              A
# 4                         6 weeks  \n              B
# ..                                ...            ...
# 96                         Demi Moore              B
# 97                  Chicago, Illinois              B
# 98                             Rachel              A
# 99                             GI Joe              B
# 100                    Carmen Miranda              B
#
#                                               response
# 0         Ross was legally divorced twice on the show.
# 1      Carol first met Susan in the pilot episode o...
# 2      In the Friends TV show, Susan and Ross came ...
# 3      Ben's first words on the Friends TV show wer...
# 4      Ross and Emily dated for approximately 6 mon...
# ..                                                 ...
# 96     Sure! The answer to your question is:\n\nMon...
# 97     The Mama's Little Bakery cheesecake that Rac...
# 98     Phoebe calls Joey a leaf blower in the episo...
# 99     Ross wants Ben to play with the GI Joe doll ...
# 100    Chandler's dad, Jack, dressed up as a woman ...
#
# [100 rows x 5 columns]

# %%
from evaluation.evaluator import Evaluator
import asyncio
from evaluation.metrics import MCQMetrics, FreeResponseMetrics

# %%
import ast

data['options'] = data['options'].apply(lambda x: ast.literal_eval(x))

# %%
data['options'] = data['options'].apply(lambda x: [option.replace('\n', ' ').strip() for option in x])

# %%
data = data[data['options'].apply(lambda x: len(x) == 4)]

# %%
data
# Out:
#                                               question  \
# 0        How many times was Ross legally divorced?  \n
# 1                Where did Carol first meet Susan?  \n
# 2      How did Susan and Ross come up with Ben’s name?
# 3                     What were Ben's first words?  \n
# 4    How long did Ross and Emily date before they g...
# ..                                                 ...
# 195  Which character claimed to have skipped fourth...
# 196  Which character was shot in the butt by a tran...
# 197  Who resolves to stop gossiping as their New Ye...
# 198                Which friend has never kissed Joey?
# 199  Who thought that when you get married in Las V...
#
#                                                options  \
# 0          [Twice, Three times, Five times, Six times]
# 1    [In college, At work, At the gym, At Central P...
# 2    [It was the doctor's name, They both had uncle...
# 3                                 [Hi, Bye, Mom, Dumb]
# 4                 [14 days, 6 weeks, A year, 3 months]
# ..                                                 ...
# 195                     [Joey, Monica, Chandler, Ross]
# 196                       [Joey, Rachel, Phoebe, Ross]
# 197                       [Monica, Ross, Rachel, Joey]
# 198                     [Rachel, Ross, Monica, Phoebe]
# 199                       [Rachel, Joey, Ross, Phoebe]
#
#                             reference correct_option  \
# 0                         Three times              B
# 1                          At the gym              C
# 2    It was on the janitor's name tag              D
# 3                                  Hi              A
# 4                         6 weeks  \n              B
# ..                                ...            ...
# 195                              Ross              D
# 196                            Phoebe              C
# 197                            Rachel              C
# 198                            Monica              C
# 199                            Phoebe              D
#
#                                               response
# 0         Ross was legally divorced twice on the show.
# 1      Carol first met Susan in the pilot episode o...
# 2      In the Friends TV show, Susan and Ross came ...
# 3      Ben's first words on the Friends TV show wer...
# 4      Ross and Emily dated for approximately 6 mon...
# ..                                                 ...
# 195                                    Joey Tribbiani.
# 196                                    Joey Tribbiani.
# 197                                      Rachel Green.
# 198    Of course! The friend who has never kissed J...
# 199    The character Joey Tribbiani from the TV sho...
#
# [199 rows x 5 columns]

# %%
class Evaluator:
    def __init__(self, data, port_number=8080):
        self.data = data
        self.api_url = f"http://localhost:{port_number}/completion"

    async def evaluate_row(self, row):
        # Extract relevant information from the dataframe row
        question = row['question']
        reference = row['reference']
        options = row['options']

        if 'response' in row:
            response = row['response']
        else:
            response = None
        
        # Create instances of metrics classes
        mcq_metrics = MCQMetrics(question=question, reference=reference, options=options)
        free_response_metrics = FreeResponseMetrics(question=question, reference=reference, response=response)

        # Run the metrics asynchronously
        mcq_result = await mcq_metrics()
        free_response_result = await free_response_metrics()

        return {
            'mcq_metrics': mcq_result,
            'free_response_metrics': free_response_result,
        }

    async def evaluate_dataframe(self):
        results = []

        for index, row in tqdm(self.data.iterrows(), desc="Evaluating rows", total=len(self.data), ncols=80):
            result = await self.evaluate_row(row)
            results.append(result)

        return results

    async def run_evaluation(self):
        results = await self.evaluate_dataframe()
        
        # print(results)
        return results

# %%
evaluator = Evaluator(data = data)

# %%
results = await evaluator.run_evaluation()
# Out:
# Evaluating rows: 100%|████████████████████████| 100/100 [23:44<00:00, 14.25s/it]

# %%
mcq_results = [result['mcq_metrics'] for result in results]
free_response_results = [result['free_response_metrics'] for result in results]
llm_mcq_answers = [result['mcq_metrics']['answer'] for result in results]

# %%
data['mcq_results'] = mcq_results
data['free_response_results'] = free_response_results
data['llm_mcq_answers'] = llm_mcq_answers
# Out:
# /var/folders/zj/8wm19rjs2zzf750trg99dd1h0000gn/T/ipykernel_41717/3748970346.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['mcq_results'] = mcq_results
# /var/folders/zj/8wm19rjs2zzf750trg99dd1h0000gn/T/ipykernel_41717/3748970346.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['free_response_results'] = free_response_results
# /var/folders/zj/8wm19rjs2zzf750trg99dd1h0000gn/T/ipykernel_41717/3748970346.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['llm_mcq_answers'] = llm_mcq_answers

# %%
data.to_csv('../data/eval_data/trivia_data_with_base_response_metrics.csv', index=False)

# %%
data
# Out:
#                                               question  \
# 0        How many times was Ross legally divorced?  \n
# 1                Where did Carol first meet Susan?  \n
# 2      How did Susan and Ross come up with Ben’s name?
# 3                     What were Ben's first words?  \n
# 4    How long did Ross and Emily date before they g...
# ..                                                 ...
# 96              Which actor's haircut did Monica want?
# 97   What city does the Mama's Little Bakery cheese...
# 98   After reading _Be Your Own Windkeeper_, who do...
# 99   When Ben shows up with a Barbie doll, what dol...
# 100  Who did Chandler’s dad dress up as when he wen...
#
#                                                options  \
# 0          [Twice, Three times, Five times, Six times]
# 1    [In college, At work, At the gym, At Central P...
# 2    [It was the doctor's name, They both had uncle...
# 3                                 [Hi, Bye, Mom, Dumb]
# 4                 [14 days, 6 weeks, A year, 3 months]
# ..                                                 ...
# 96   [Winona Ryder, Demi Moore, Terri Hatcher, Juli...
# 97   [Albany, New York, Chicago, Illinois, Boston, ...
# 98   [Rachel, Monica, None of the above, All of the...
# 99   [Action Man, GI Joe, Optimus Prime, Stretch Ar...
# 100  [Marilyn Monroe, Carmen Miranda, Mae West, Luc...
#
#                             reference correct_option  \
# 0                         Three times              B
# 1                          At the gym              C
# 2    It was on the janitor's name tag              D
# 3                                  Hi              A
# 4                         6 weeks  \n              B
# ..                                ...            ...
# 96                         Demi Moore              B
# 97                  Chicago, Illinois              B
# 98                             Rachel              A
# 99                             GI Joe              B
# 100                    Carmen Miranda              B
#
#                                               response  \
# 0         Ross was legally divorced twice on the show.
# 1      Carol first met Susan in the pilot episode o...
# 2      In the Friends TV show, Susan and Ross came ...
# 3      Ben's first words on the Friends TV show wer...
# 4      Ross and Emily dated for approximately 6 mon...
# ..                                                 ...
# 96     Sure! The answer to your question is:\n\nMon...
# 97     The Mama's Little Bakery cheesecake that Rac...
# 98     Phoebe calls Joey a leaf blower in the episo...
# 99     Ross wants Ben to play with the GI Joe doll ...
# 100    Chandler's dad, Jack, dressed up as a woman ...
#
#                                            mcq_results  \
# 0    {'correct_format_rate': 1.0, 'correct_answer_r...
# 1    {'correct_format_rate': 1.0, 'correct_answer_r...
# 2    {'correct_format_rate': 1.0, 'correct_answer_r...
# 3    {'correct_format_rate': 1.0, 'correct_answer_r...
# 4    {'correct_format_rate': 0.6, 'correct_answer_r...
# ..                                                 ...
# 96   {'correct_format_rate': 1.0, 'correct_answer_r...
# 97   {'correct_format_rate': 1.0, 'correct_answer_r...
# 98   {'correct_format_rate': 1.0, 'correct_answer_r...
# 99   {'correct_format_rate': 1.0, 'correct_answer_r...
# 100  {'correct_format_rate': 1.0, 'correct_answer_r...
#
#                                  free_response_results llm_mcq_answers
# 0    {'average_score': 0.03004698047801498, 'bleu':...               B
# 1    {'average_score': 0.1284215806951859, 'bleu': ...               B
# 2    {'average_score': 0.12931685168564777, 'bleu':...               B
# 3    {'average_score': 0.013020833333333356, 'bleu'...               B
# 4    {'average_score': 0.07069338899834257, 'bleu':...               B
# ..                                                 ...             ...
# 96   {'average_score': 0.02805983504512918, 'bleu':...               B
# 97   {'average_score': 0.033257536720762, 'bleu': 0...               B
# 98   {'average_score': 0.019346834058839628, 'bleu'...               B
# 99   {'average_score': 0.20356027128813167, 'bleu':...               B
# 100  {'average_score': 0.039283239283239305, 'bleu'...               B
#
# [100 rows x 8 columns]

# %%
len(data[data.llm_mcq_answers == data.correct_option])
# Out:
# 36

# %%
data['correct_format_rate'] = data['mcq_results'].apply(lambda x: x['correct_format_rate'])
# data['correct_answer_rate'] = data['mcq_results'].apply(lambda x: x['correct_answer_rate'])
data['average_score'] = data['free_response_results'].apply(lambda x: x['average_score'])
# Out:
# /var/folders/zj/8wm19rjs2zzf750trg99dd1h0000gn/T/ipykernel_41717/3750448606.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['correct_format_rate'] = data['mcq_results'].apply(lambda x: x['correct_format_rate'])
# /var/folders/zj/8wm19rjs2zzf750trg99dd1h0000gn/T/ipykernel_41717/3750448606.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['correct_answer_rate'] = data['mcq_results'].apply(lambda x: x['correct_answer_rate'])
# /var/folders/zj/8wm19rjs2zzf750trg99dd1h0000gn/T/ipykernel_41717/3750448606.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['average_score'] = data['free_response_results'].apply(lambda x: x['average_score'])

# %%
print('MCQ Results:')
print('MCQ Accuracy: ', len(data[data.llm_mcq_answers == data.correct_option]) / len(data))
print('Correct format rate: ', data['correct_format_rate'].mean())
# print('Correct answer rate: ', data['correct_answer_rate'].mean())
print('Free Response Results:')
print('Average score: ', data['average_score'].mean())
# Out:
# MCQ Results:
# MCQ Accuracy:  0.36
# Correct format rate:  0.98
# Correct answer rate:  0.0
# Free Response Results:
# Average score:  0.04264022092631699
